# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
img = cv2.imread("../assets/imori.jpg",1)

# %%
w, h = 60,60

# %%
img = cv2.resize(img, (w, h))
plt.imshow(img[:,:,::-1])
