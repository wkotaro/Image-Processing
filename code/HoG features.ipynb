# %%
import cv2
from matplotlib import pyplot as plt
from skimage.feature import hog
from skimage import data, exposure

# %%
img = cv2.imread("../assets/imori.jpg")

# %%
fd, hog_img = hog(img, orientations=8, pixels_per_cell=(8,8), 
                 cells_per_block=(1,1), visualize=True, multichannel=True)

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(8, 4), sharex=True, sharey=True)
ax1.axis("off")
ax1.imshow(img[:,:,::-1], cmap=plt.cm.gray)
ax1.set_title("Input image")

hog_img_rescaled = exposure.rescale_intensity(hog_img, in_range=(0,8))

ax2.axis("off")
ax2.imshow(hog_img_rescaled, cmap=plt.cm.gray)
ax2.set_title("Histogram of Gradients")
# Out:
# Text(0.5, 1.0, 'Histogram of Gradients')
