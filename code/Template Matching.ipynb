# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
# Original image
img = cv2.imread("../assets/imori.jpg")
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
plt.imshow(gray, cmap="gray")

# %%
# Template image
template = cv2.imread("../assets/imori_part.jpg", 0)
w, h = template.shape[::-1]
plt.figure(figsize=(1,1))
plt.imshow(template, cmap="gray")

# %%
# Template matching  SAD
img1 = img.copy()
match1 = cv2.matchTemplate(gray, template, cv2.TM_SQDIFF_NORMED)
min_value1, max_value1, min_pt1, max_pt1 = cv2.minMaxLoc(match1)
pt1 = min_pt1

# %%
# Create rectangle
cv2.rectangle(img1, (pt1[0], pt1[1]), (pt1[0] + w, pt1[1] + h), (0, 0, 200), 2)
plt.imshow(img1[:, :, ::-1])

# %%
# Template matching SSD
img2 = img.copy()
match2 = cv2.matchTemplate(gray, template, cv2.TM_SQDIFF)
min_value2, max_value2, min_pt2, max_pt2 = cv2.minMaxLoc(match2)
pt2 = min_pt2

# %%
# Create rectangle
cv2.rectangle(img2, (pt2[0], pt2[1]), (pt2[0] + w, pt2[1] + h), (0, 0, 200), 2)
plt.imshow(img2[:, :, ::-1])

# %%
# Templating Matching ZNCC
match3 = cv2.matchTemplate(gray, template, cv2.TM_CCOEFF_NORMED)
min_value3, max_value3, min_pt3, max_pt3 = cv2.minMaxLoc(match3)
pt3 = max_pt3

# %%
# Create rectangle
img3 = img.copy()
cv2.rectangle(img3, (pt3[0], pt3[1]), (pt3[0] + w, pt3[1] + h), (0, 0, 200), 2)
plt.imshow(img3[:, :, ::-1])

# %%
# Templating Matching NCC
match4 = cv2.matchTemplate(gray, template, cv2.TM_CCORR_NORMED)
min_value4, max_value4, min_pt4, max_pt4 = cv2.minMaxLoc(match4)
pt4 = max_pt4

# %%
# Create rectangle
img4= img.copy()
cv2.rectangle(img4, (pt4[0], pt4[1]), (pt4[0] + w, pt4[1] + h), (0, 0, 200), 2)
plt.imshow(img4[:, :, ::-1])
